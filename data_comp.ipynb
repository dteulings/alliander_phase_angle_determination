# %%
import pyarrow.feather as feather
import pandas as pd
from datetime import datetime
import numpy as np
import math

import sklearn.gaussian_process as gp
import matplotlib.pyplot as plt

# %%
old_2_weeks = feather.read_feather('old_2_weeks_crossval_results.feather')
old_station = feather.read_feather('old_station_crossval_results.feather')

new_2_weeks = feather.read_feather('2_weeks_crossval_results.feather')
new_station = feather.read_feather('station_crossval_results.feather')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 4
#       1 old_2_weeks = feather.read_feather('old_2_weeks_crossval_results.feather')
#       2 old_station = feather.read_feather('old_station_crossval_results.feather')
# ----> 4 new_2_weeks = feather.read_feather('2_weeks_crossval_results.feather')
#       5 new_station = feather.read_feather('station_crossval_results.feather')
#
# File ~\anaconda3\envs\alliander\lib\site-packages\pyarrow\feather.py:220, in read_feather(source, columns, use_threads, memory_map)
#     198 """
#     199 Read a pandas.DataFrame from Feather format. To read as pyarrow.Table use
#     200 feather.read_table.
#    (...)
#     217 df : pandas.DataFrame
#     218 """
#     219 _check_pandas_version()
# --> 220 return (read_table(source, columns=columns, memory_map=memory_map)
#     221         .to_pandas(use_threads=use_threads))
#
# ...

# %%
old_station
# Out:
#     level_0         index  trained_on_0  trained_on_1  trained_on_2  \
# 0         0   tested_on_0      0.933532      0.892688      0.898115
# 1         1   tested_on_1      0.893879      0.931915      0.891468
# 2         2   tested_on_2      0.897897      0.891687      0.929038
# 3         3   tested_on_3      0.897897      0.896984      0.894484
# 4         4   tested_on_4      0.897897      0.896984      0.898115
# 5         5   tested_on_5      0.897897      0.896984      0.898115
# 6         6   tested_on_6      0.897897      0.896984      0.898115
# 7         7   tested_on_7      0.897897      0.896984      0.898115
# 8         8   tested_on_8      0.897897      0.896984      0.898115
# 9         9   tested_on_9      0.897897      0.896984      0.898115
# 10       10  tested_on_10      0.897897      0.896984      0.898115
# 11       11  tested_on_11      0.897897      0.896984      0.898115
# 12       12  tested_on_12      0.897897      0.896984      0.898115
# ...
